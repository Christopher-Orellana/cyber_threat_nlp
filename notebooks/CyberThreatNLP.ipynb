# %%
import pandas as pd

# %%
data_path = r'C:\Users\User\Documents\school\Data Analysis projects\cyber_threat_nlp\data\TheHackerNews_Dataset.xlsx'

# %%
df = pd.read_excel(data_path, engine='openpyxl')

# %%
df
# Out:
#                                                   Title  \
# 0     Critical Cosmos Database Flaw Affected Thousan...
# 1     Researchers Detail Modus Operandi of ShinyHunt...
# 2     Chinese Hackers Believed to be Behind Second C...
# 3     Using Breached Password Detection Services to ...
# 4     Can Data Protection Systems Prevent Data At Re...
# ...                                                 ...
# 3737    Chinese hackers attack on White House computers
# 3738          Cyber Attacks on Six Major American Banks
# 3739      9 million PCs infected with ZeroAccess botnet
# 3740  Bharatiya Janata Party website defaced by Anon...
# 3741  Bank of America Website under Cyber Attack fro...
#
#                                                    Link  \
# 0     https://thehackernews.com/2021/08/critical-cos...
# 1     https://thehackernews.com/2021/08/researchers-...
# 2     https://thehackernews.com/2021/06/chinese-hack...
# 3     https://thehackernews.com/2021/06/using-breach...
# 4     https://thehackernews.com/2021/05/can-data-pro...
# ...                                                 ...
# 3737  https://thehackernews.com/2012/10/chinese-hack...
# 3738  https://thehackernews.com/2012/10/cyber-attack...
# 3739  https://thehackernews.com/2012/09/9-million-pc...
# 3740  https://thehackernews.com/2012/09/bharatiya-ja...
# 3741  https://thehackernews.com/2012/09/bank-of-amer...
#
#                                                 Article          Label
# 0     Cloud infrastructure security company Wiz on T...  Data_Breaches
# 1     ShinyHunters, a notorious cybercriminal underg...  Data_Breaches
# 2     Even as a massive data breach affecting Air In...  Data_Breaches
# 3     Bolstering password policies in your organizat...  Data_Breaches
# 4     Protection against insider risks works when th...  Data_Breaches
# ...                                                 ...            ...
# 3737  The White House acknowledged Monday that one o...   Cyber_Attack
# 3738  According to reports, some of the United State...   Cyber_Attack
# 3739  In recent months, we've seen the rootkit famil...   Cyber_Attack
# 3740  Hackers from Indian Anonymous Group hacked Bha...   Cyber_Attack
# 3741  Bank of America's website experienced periodic...   Cyber_Attack
#
# [3742 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3742 entries, 0 to 3741
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Title    3742 non-null   object
#  1   Link     3742 non-null   object
#  2   Article  3742 non-null   object
#  3   Label    3742 non-null   object
# dtypes: object(4)
# memory usage: 117.1+ KB

# %%
df.describe()
# Out:
#                                                     Title  \
# count                                                3742
# unique                                               3223
# top     Importance of Logs and Log Management for IT S...
# freq                                                    3
#
#                                                      Link  \
# count                                                3742
# unique                                               3223
# top     https://thehackernews.com/2013/10/importance-o...
# freq                                                    3
#
#                                                   Article          Label
# count                                                3742           3742
# unique                                               3224              4
# top     Cyber operatives affiliated with the Russian F...  Vulnerability
# freq                                                    3           1352
